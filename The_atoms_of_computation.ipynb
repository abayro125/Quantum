# %% [markdown]
# <a href="https://colab.research.google.com/github/abayro125/Quantum/blob/main/The_atoms_of_computation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Splitting information into bits**
#
# The binary number system is based on the number two. For example:
#
# ![Screen Shot 2022-11-09 at 1.21.01 PM.png](data:image/png;base64,...)

# %% [markdown]
# ** Circuit Diagrams**
#
# These diagrams have inputs on the left, outputs on the right and operations represented by arcane symbols in between. These operations are called "gates".
#
# ![Screen Shot 2022-11-09 at 1.22.53 PM.png](data:image/png;base64,...)

# %% [markdown]
# Example of quantum circuit:
#
# ![Screen Shot 2022-11-09 at 1.23.31 PM.png](data:image/png;base64,...)

# %%
from qiskit import QuantumCircuit
# Create quantum circuit with 3 qubits and 3 classical bits
# (we'll explain why we need the classical bits later)
qc = QuantumCircuit(3, 3)
qc.draw()  # returns a drawing of the circuit
# Out:
#
# q_0:
#
# q_1:
#
# q_2:
#
# c_0:
#
# c_1:
#
# c_2:

# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit(3, 3)
# measure qubits 0, 1 & 2 to classical bits 0, 1 & 2 respectively
qc.measure([0,1,2], [0,1,2])
qc.draw()
# Out:
#      ┌─┐
# q_0: ┤M├──────
#      └╥┘┌─┐
# q_1: ─╫─┤M├───
#       ║ └╥┘┌─┐
# q_2: ─╫──╫─┤M├
#       ║  ║ └╥┘
# c_0: ═╩══╬══╬═
#          ║  ║
# c_1: ════╩══╬═
#             ║
# c_2: ═══════╩═

# %%
from qiskit.providers.aer import AerSimulator
sim = AerSimulator()  # make new simulator object

job = sim.run(qc)      # run the experiment
result = job.result()  # get the results
result.get_counts()    # interpret the results as a "counts" dictionary
# Out:
# {'000': 1024}

# %%
# Create quantum circuit with 3 qubits and 3 classical bits:
qc = QuantumCircuit(3, 3)
qc.x([0,1])  # Perform X-gates on qubits 0 & 1
qc.measure([0,1,2], [0,1,2])
qc.draw()    # returns a drawing of the circuit
# Out:
#      ┌───┐┌─┐
# q_0: ┤ X ├┤M├───
#      ├───┤└╥┘┌─┐
# q_1: ┤ X ├─╫─┤M├
#      └┬─┬┘ ║ └╥┘
# q_2: ─┤M├──╫──╫─
#       └╥┘  ║  ║
# c_0: ══╬═══╩══╬═
#        ║      ║
# c_1: ══╬══════╩═
#        ║
# c_2: ══╩════════

# %%
job = sim.run(qc)      # run the experiment
result = job.result()  # get the results
result.get_counts()    # interpret the results as a "counts" dictionary
# Out:
# {'011': 1024}

# %%
# Create quantum circuit with 2 qubits and 2 classical bits
qc = QuantumCircuit(2, 2)
qc.x(0)
qc.cx(0,1)  # CNOT controlled by qubit 0 and targeting qubit 1
qc.measure([0,1], [0,1])
display(qc.draw())     # display a drawing of the circuit

job = sim.run(qc)      # run the experiment
result = job.result()  # get the results
# interpret the results as a "counts" dictionary
print("Result: ", result.get_counts())
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ X ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c_0: ═══════════╩══╬═
#                    ║
# c_1: ══════════════╩═
# Result:  {'11': 1024}
